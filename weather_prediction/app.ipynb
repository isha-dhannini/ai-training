# %%
# !pip install requests pandas
# Out:
# Requirement already satisfied: requests in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (2.34.2)
# Requirement already satisfied: pandas in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (2.3.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (from requests) (3.17)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (from requests) (2026.5.20)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Administrator\Learnings\ai-training\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd
from datetime import datetime

API_KEY = "f559015c61069e5935b5ee8258a9214b"
CITY = "Bangalore"

url = (
    f"https://api.openweathermap.org/data/2.5/weather"
    f"?q={CITY}&appid={API_KEY}&units=metric"
)

response = requests.get(url)
data = response.json()

weather_record = {
    "timestamp": datetime.now(),
    "city": data["name"],
    "temperature": data["main"]["temp"],
    "feels_like": data["main"]["feels_like"],
    "humidity": data["main"]["humidity"],
    "pressure": data["main"]["pressure"],
    "wind_speed": data["wind"]["speed"],
    "weather": data["weather"][0]["main"]
}

df = pd.DataFrame([weather_record])

df.to_csv("weather_data.csv", index=False)

print(df)
# Out:
#                    timestamp       city  temperature  feels_like  humidity  \
# 0 2026-06-07 16:12:58.159318  Bengaluru        27.56       29.41        66
#
#    pressure  wind_speed weather
# 0      1009       13.86  Clouds
